# %% [markdown]
# ## Multi classification problem using pytorch
# ### Datasets from sklearn (wine)
# #### Each wine has 13 features which are 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline' and can be classified into 3 types.

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import random
import torch
from torch import nn
loaded_data = datasets.load_wine()
data_X = loaded_data.data
data_Y = loaded_data.target
print(loaded_data.feature_names,"\n",loaded_data.target_names)
data_X = torch.from_numpy(data_X)
data_Y = torch.from_numpy(data_Y)
data_Y = data_Y.type(torch.long)
#print(data_X)
print(data_X)
#print(train_data_X,"\n",test_data_X)
input_size = data_X.shape[1]
output_size = 3
print(data_Y.type)
# Out:
# ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
#  ['class_0' 'class_1' 'class_2']
# tensor([[1.4230e+01, 1.7100e+00, 2.4300e+00,  ..., 1.0400e+00, 3.9200e+00,
#          1.0650e+03],
#         [1.3200e+01, 1.7800e+00, 2.1400e+00,  ..., 1.0500e+00, 3.4000e+00,
#          1.0500e+03],
#         [1.3160e+01, 2.3600e+00, 2.6700e+00,  ..., 1.0300e+00, 3.1700e+00,
#          1.1850e+03],
#         ...,
#         [1.3270e+01, 4.2800e+00, 2.2600e+00,  ..., 5.9000e-01, 1.5600e+00,
#          8.3500e+02],
#         [1.3170e+01, 2.5900e+00, 2.3700e+00,  ..., 6.0000e-01, 1.6200e+00,
#          8.4000e+02],
#         [1.4130e+01, 4.1000e+00, 2.7400e+00,  ..., 6.1000e-01, 1.6000e+00,
#          5.6000e+02]], dtype=torch.float64)
# <built-in method type of Tensor object at 0x000002306CC9CA40>

# %%
train_num = 120
index = random.sample(range(0,178), train_num)
a = list(range(0,178))
for i in index:
    a.remove(i)
print(index)
print(a)
# Out:
# [50, 119, 46, 131, 64, 105, 130, 58, 84, 97, 111, 106, 77, 157, 121, 76, 56, 90, 10, 42, 177, 173, 153, 167, 65, 102, 158, 11, 146, 72, 150, 27, 109, 23, 104, 125, 99, 12, 160, 69, 51, 78, 39, 20, 147, 148, 171, 82, 37, 31, 144, 107, 57, 81, 54, 100, 32, 28, 138, 48, 124, 141, 5, 110, 135, 91, 43, 70, 166, 24, 164, 134, 170, 95, 168, 112, 29, 151, 36, 49, 71, 122, 89, 16, 155, 0, 156, 123, 26, 140, 162, 176, 149, 101, 17, 74, 18, 161, 73, 92, 159, 47, 98, 35, 113, 94, 86, 67, 44, 9, 133, 172, 13, 21, 165, 108, 66, 15, 34, 60]
# [1, 2, 3, 4, 6, 7, 8, 14, 19, 22, 25, 30, 33, 38, 40, 41, 45, 52, 53, 55, 59, 61, 62, 63, 68, 75, 79, 80, 83, 85, 87, 88, 93, 96, 103, 114, 115, 116, 117, 118, 120, 126, 127, 128, 129, 132, 136, 137, 139, 142, 143, 145, 152, 154, 163, 169, 174, 175]

# %% [markdown]
# #### torch.index_select can select special index contant in a torch tensor

# %%
train_data_X = torch.index_select(data_X, 0, torch.tensor(index))
train_data_Y = torch.index_select(data_Y, 0, torch.tensor(index))
test_data_X = torch.index_select(data_X, 0, torch.tensor(a))
test_data_Y = torch.index_select(data_Y, 0, torch.tensor(a))
print(train_data_X.shape,train_data_Y.shape,test_data_X.shape,test_data_Y.shape)
print(train_data_Y)
# Out:
# torch.Size([120, 13]) torch.Size([120]) torch.Size([58, 13]) torch.Size([58])
# tensor([0, 1, 0, 2, 1, 1, 2, 0, 1, 1, 1, 1, 1, 2, 1, 1, 0, 1, 0, 0, 2, 2, 2, 2,
#         1, 1, 2, 0, 2, 1, 2, 0, 1, 0, 1, 1, 1, 0, 2, 1, 0, 1, 0, 0, 2, 2, 2, 1,
#         0, 0, 2, 1, 0, 1, 0, 1, 0, 0, 2, 0, 1, 2, 0, 1, 2, 1, 0, 1, 2, 0, 2, 2,
#         2, 1, 2, 1, 0, 2, 0, 0, 1, 1, 1, 0, 2, 0, 2, 1, 0, 2, 2, 2, 2, 1, 0, 1,
#         0, 2, 1, 1, 2, 0, 1, 0, 1, 1, 1, 1, 0, 0, 2, 2, 0, 0, 2, 1, 1, 0, 0, 1])

# %%
# inherit nn.Module
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        self.layer1 = nn.Linear(13,10)
        self.layer2 = nn.Linear(10,3)
    def forward(self,x):
        y = self.layer1(x)
        y = self.layer2(y)
        return y

# %%
net = Net()
net.double()
loss = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.001)

# %%
#train
net.double()
def train():
    train_l = 0.0
    y_hat = net(train_data_X)
    l = loss(y_hat, train_data_Y).sum()
    
    optimizer.zero_grad()

    l.backward()

    optimizer.step()
    train_l = l
    print('epoch %d, loss %.4f' % (epoch + 1, train_l))
    return train_l

# %%
#test
def test():
    correct = 0
    total = 0
    for data in test_data_X:
        test = net(data)
        _, predict = torch.max(test.data, dim=0)
        #print(predict.item(), test_data_Y[total].item())
        if(predict.item() == test_data_Y[total].item()): 
            correct+=1
        total +=1
    print("correct rate = ",100 * correct/total)
    return 100 * correct/total *0.01

# %%
lss = []
acc = []
epochs = []
for epoch in range(100):
    epochs.append(epoch+1)
    ls = train();
    ac = test();
    l_tmp = ls.detach().numpy()
    lss.append(l_tmp)
    acc.append(ac);
    
plt.plot(epochs,acc,color='r',label='accuracy')  
plt.xlabel('epochs')    
plt.ylabel('y label')   
plt.title("chart")      
plt.legend()   
plt.show()

plt.plot(epochs,lss,color=(0,0,0),label='loss')
plt.xlabel('epochs')    
plt.ylabel('y label')   
plt.title("chart")      
plt.legend()            
plt.show()
# Out:
# epoch 1, loss 47.3941
# correct rate =  43.10344827586207
# epoch 2, loss 94.3637
# correct rate =  22.413793103448278
# epoch 3, loss 81.8685
# correct rate =  34.48275862068966
# epoch 4, loss 74.1181
# correct rate =  43.10344827586207
# epoch 5, loss 27.9435
# correct rate =  34.48275862068966
# epoch 6, loss 30.4390
# correct rate =  22.413793103448278
# epoch 7, loss 22.0370
# correct rate =  39.6551724137931
# epoch 8, loss 20.2240
# correct rate =  43.10344827586207
# epoch 9, loss 17.5405
# correct rate =  34.48275862068966
# epoch 10, loss 8.4918
# correct rate =  22.413793103448278
# epoch 11, loss 7.8045
# correct rate =  65.51724137931035
# epoch 12, loss 7.1125
# correct rate =  53.44827586206897
# epoch 13, loss 4.8842
# correct rate =  41.37931034482759
# epoch 14, loss 4.0555
# correct rate =  46.55172413793103
# epoch 15, loss 1.0524
# correct rate =  70.6896551724138
# epoch 16, loss 1.9340
# correct rate =  70.6896551724138
# epoch 17, loss 0.7502
# correct rate =  70.6896551724138
# epoch 18, loss 0.8534
# correct rate =  68.96551724137932
# epoch 19, loss 1.2128
# correct rate =  74.13793103448276
# epoch 20, loss 0.7973
# correct rate =  70.6896551724138
# epoch 21, loss 0.9097
# correct rate =  60.3448275862069
# epoch 22, loss 0.8853
# correct rate =  68.96551724137932
# epoch 23, loss 1.0278
# correct rate =  74.13793103448276
# epoch 24, loss 0.7643
# correct rate =  68.96551724137932
# epoch 25, loss 0.8051
# correct rate =  74.13793103448276
# epoch 26, loss 0.7755
# correct rate =  68.96551724137932
# epoch 27, loss 0.8200
# correct rate =  75.86206896551724
# epoch 28, loss 0.7463
# correct rate =  68.96551724137932
# epoch 29, loss 0.7701
# correct rate =  75.86206896551724
# epoch 30, loss 0.7252
# correct rate =  68.96551724137932
# epoch 31, loss 0.7380
# correct rate =  74.13793103448276
# epoch 32, loss 0.7082
# correct rate =  68.96551724137932
# epoch 33, loss 0.7144
# correct rate =  70.6896551724138
# epoch 34, loss 0.6949
# correct rate =  68.96551724137932
# epoch 35, loss 0.6974
# correct rate =  68.96551724137932
# epoch 36, loss 0.6846
# correct rate =  68.96551724137932
# epoch 37, loss 0.6851
# correct rate =  68.96551724137932
# epoch 38, loss 0.6768
# correct rate =  68.96551724137932
# epoch 39, loss 0.6763
# correct rate =  68.96551724137932
# epoch 40, loss 0.6709
# correct rate =  68.96551724137932
# epoch 41, loss 0.6700
# correct rate =  68.96551724137932
# epoch 42, loss 0.6663
# correct rate =  70.6896551724138
# epoch 43, loss 0.6653
# correct rate =  68.96551724137932
# epoch 44, loss 0.6629
# correct rate =  70.6896551724138
# epoch 45, loss 0.6619
# correct rate =  68.96551724137932
# epoch 46, loss 0.6602
# correct rate =  70.6896551724138
# epoch 47, loss 0.6593
# correct rate =  72.41379310344827
# epoch 48, loss 0.6580
# correct rate =  70.6896551724138
# epoch 49, loss 0.6573
# correct rate =  72.41379310344827
# epoch 50, loss 0.6563
# correct rate =  70.6896551724138
# epoch 51, loss 0.6556
# correct rate =  68.96551724137932
# epoch 52, loss 0.6549
# correct rate =  70.6896551724138
# epoch 53, loss 0.6543
# correct rate =  68.96551724137932
# epoch 54, loss 0.6536
# correct rate =  72.41379310344827
# epoch 55, loss 0.6531
# correct rate =  68.96551724137932
# epoch 56, loss 0.6526
# correct rate =  72.41379310344827
# epoch 57, loss 0.6521
# correct rate =  70.6896551724138
# epoch 58, loss 0.6516
# correct rate =  72.41379310344827
# epoch 59, loss 0.6512
# correct rate =  70.6896551724138
# epoch 60, loss 0.6507
# correct rate =  72.41379310344827
# epoch 61, loss 0.6503
# correct rate =  70.6896551724138
# epoch 62, loss 0.6499
# correct rate =  74.13793103448276
# epoch 63, loss 0.6494
# correct rate =  70.6896551724138
# epoch 64, loss 0.6490
# correct rate =  74.13793103448276
# epoch 65, loss 0.6487
# correct rate =  70.6896551724138
# epoch 66, loss 0.6483
# correct rate =  74.13793103448276
# epoch 67, loss 0.6479
# correct rate =  70.6896551724138
# epoch 68, loss 0.6475
# correct rate =  74.13793103448276
# epoch 69, loss 0.6471
# correct rate =  70.6896551724138
# epoch 70, loss 0.6467
# correct rate =  72.41379310344827
# epoch 71, loss 0.6464
# correct rate =  70.6896551724138
# epoch 72, loss 0.6460
# correct rate =  72.41379310344827
# epoch 73, loss 0.6456
# correct rate =  70.6896551724138
# epoch 74, loss 0.6453
# correct rate =  72.41379310344827
# epoch 75, loss 0.6449
# correct rate =  70.6896551724138
# epoch 76, loss 0.6445
# correct rate =  72.41379310344827
# epoch 77, loss 0.6442
# correct rate =  70.6896551724138
# epoch 78, loss 0.6438
# correct rate =  72.41379310344827
# epoch 79, loss 0.6435
# correct rate =  70.6896551724138
# epoch 80, loss 0.6431
# correct rate =  72.41379310344827
# epoch 81, loss 0.6428
# correct rate =  70.6896551724138
# epoch 82, loss 0.6424
# correct rate =  72.41379310344827
# epoch 83, loss 0.6420
# correct rate =  70.6896551724138
# epoch 84, loss 0.6417
# correct rate =  72.41379310344827
# epoch 85, loss 0.6413
# correct rate =  70.6896551724138
# epoch 86, loss 0.6410
# correct rate =  72.41379310344827
# epoch 87, loss 0.6406
# correct rate =  70.6896551724138
# epoch 88, loss 0.6403
# correct rate =  72.41379310344827
# epoch 89, loss 0.6399
# correct rate =  70.6896551724138
# epoch 90, loss 0.6396
# correct rate =  72.41379310344827
# epoch 91, loss 0.6392
# correct rate =  70.6896551724138
# epoch 92, loss 0.6389
# correct rate =  74.13793103448276
# epoch 93, loss 0.6386
# correct rate =  70.6896551724138
# epoch 94, loss 0.6382
# correct rate =  74.13793103448276
# epoch 95, loss 0.6379
# correct rate =  70.6896551724138
# epoch 96, loss 0.6375
# correct rate =  74.13793103448276
# epoch 97, loss 0.6372
# correct rate =  70.6896551724138
# epoch 98, loss 0.6368
# correct rate =  74.13793103448276
# epoch 99, loss 0.6365
# correct rate =  70.6896551724138
# epoch 100, loss 0.6362
# correct rate =  74.13793103448276
